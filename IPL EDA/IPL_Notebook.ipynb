# %% [markdown]
# # Exploratory Data Analysis of IPL Data Set

# %% [markdown]
# ## Table of Contents
#
# 1. [Problem Statement](#section1)<br/>
# 2. [Data Loading and Description](#section2)
# 3. [Importing necessary Packages and Dataset](#section3)
# 3. [Data Profiling](#section4)
#     - 4.1 [Understanding the Dataset](#section41)<br/>
#     - 4.2 [Pre Profiling](#section42)<br/>
#     - 4.3 [Pre Processing](#section43)<br/>
#     - 4.4 [Post Profiling](#section44)<br/>
# 5. [Questions](#section5)
#     - 5.01 [How many matches and seasons we have in our dataset ?](#section501)
#     - 5.02 [How many number of toss won by teams ?](#section502)<br/>
#     - 5.03 [What teams have preffered after winning the toss ?](#section503)<br/>
#     - 5.04 [Has toss winning helped teams in winning matches ?](#section504)<br/>
#     - 5.05 [Has choosing bat/bowl helped team in winning matches ?](#section505)<br/>
#     - 5.06 [Which team has won by maximum runs ?](#section506)<br/>
#     - 5.07 [Which teams has won by maximum wickets ?](#section507)<br/>
#     - 5.08 [Which teams has won by minimum runs ?](#section508)<br/>
#     - 5.09 [Which teams has won by minimum wickets ?](#section509)<br/>
#     - 5.10 [Which are best defending and chasing venues ?](#section510)<br/>
#     - 5.11 [Which are best defending and chasing teams ?](#section511)<br/>
#     - 5.12 [Which teams have played more number of matches ?](#section512)<br/>
#     - 5.13 [Count of matches won per season for each team?](#section513)<br/>
#     - 5.14 [Which teams have won more number of matches ?](#section514)<br/>
#     - 5.15 [Which season has most number of matches ?](#section515)<br/>
#     - 5.16 [Who are the top match winners ?](#section516)<br/>
#     - 5.17 [In which city weather has affected more matches ?](#section517)<br/>
#     - 5.18 [Checking corelation between different variables?](#section518)<br/>
#     - 5.19 [Which Team has won most IPL trophies ?](#section519)<br/>
#     - 5.20 [Distribution of winning teams percentage throughout ?](#section520)
# 6. [Conclusion](#section6)

# %% [markdown]
# ### 1. Problem Statement <a class="anchor" id="section1"></a>

# %% [markdown]
# This notebook focuses on __Exploratory Data Analysis(EDA)__ of __Indian Premiere League(IPL)__ Data Set  and derive meaningful insights , which includes __cleaning__, __reshaping__,__slicing__,__manipulating__ and __transforming__ the data.
#
# * __Exploratory Data Analysis__ <br/>
# EDA refers to critical process of performing initial investigation on data, we will have a closer look of IPL data to resolve data ambiguities by doing below :
#     - Finding Patterns in Data
#     - Checking Assumptions
#     - Handling missing Values if any
#     - Determining Relationship between Variables in Data

# %% [markdown]
# ### 2. Data Loading and description <a class="anchor" id="section2"></a>
# <img src="https://i0.wp.com/www.eventstodayz.com/wp-content/uploads/2018/02/ipl-logo-2018-images-free.jpg?resize=768%2C432&ssl=1.png">

# %% [markdown]
# - The data set consists of information about __IPL__ matches ranging from 2008-2018. Various variables present in the dataset includes data of season,city,date,team,umpires etc.
# - The data set consist of __696 observtions from 18 columns__. Below is table showing names of all columns and their description:

# %% [markdown]
# | Column Name        | Description                                                     |
# | -------------      |:-------------                                              :    |
# | ID                 | Match id                                                        |
# | Season             | IPL year                                                        |
# | City               | Match city                                                      |
# | Date               | Date of match                                                   |
# | Team1              | Playing Team1                                                   |
# | Team2              | Playing Team2                                                   |
# | Toss_Winner        | Toss Winning Team                                               |
# | Toss_Decision      | Toss winning team decision<br> to Bat/Bowl first                |
# | Result             | Type of Result                                                  |
# | DL Applied         | Duckworth Lewis method applied<br> or not in case of bad weather|
# | Winner             | Winning team                                                    |
# | Win_by_Runs        | Margin of runs for winning team                                 |
# | Win_by_Wickets     | Margin of wickets for winning team                              |
# | Player_of_match    | Best player of match                                            |
# | Venue              | Stadium Name                                                    |
# | Umpire1            | Primary umpire                                                  |
# | Umpire2            | Secondary umpire                                                |
# | Umpire3            | TV umpire                                                       |

# %% [markdown]
# ### Some Useful Insights
#
# The __Indian Premier League (IPL)__, is a professional Twenty20(refers to 20 over per innings) cricket league in India contested during April and May of every year by teams representing at least 8 Indian cities and some states. The league was founded by the __Board of Control for Cricket in India (BCCI) in 2008__. The __IPL__ is the most-attended cricket league in the world. Top Cricket Players from all over the world participate in this league. __IPL__ since its onset, 10 years ago, has been a platform for the young cricketers to showcase their skills and to adapt to the competitive atmosphere along with the foreign players as their teammates.
#
# Each team plays each other twice in a home-and-away round-robin format in the league phase. At the conclusion of the league stage, the top four teams will qualify for the playoffs. The __top two teams__ from the league phase will play against each other in the first __Qualifying match__, with the winner going straight to the __IPL final__ and the loser getting another __chance to qualify__ for the IPL final by playing the second Qualifying match. Meanwhile, the third and fourth place teams from league phase play against each other in an eliminator match and the winner from that match will play the loser from the first Qualifying match. The winner of the second Qualifying match will move onto the final to play the winner of the first Qualifying match in the IPL Final match, where the winner will be crowned the __Indian Premier League champions__.

# %% [markdown]
# ### 3. Importing necessary Packages and dataset <a class="anchor" id="section3"></a>

# %% [markdown]
# #### Importing packages

# %%
import numpy as np                                                 # Implemennts milti-dimensional array and matrices
import pandas as pd                                                # For data manipulation and analysis
import pandas_profiling as pp
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns #Provides a high level interface for drawing attractive and informative statistical graphics
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore") # Filtering Warnings in case any.

# %% [markdown]
# ### Importing the Dataset

# %%
IPLdf = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/matches.csv') #Reading CSV from Github Link

# %% [markdown]
# ### 4. Data Profiling <a class="anchor" id="section4"></a>

# %% [markdown]
# - In this sections we will __understand our dataset__ using various pandas functionalities.
# - Then with the help of __pandas profiling__ we will find which columns of our dataset need preprocessing.
# - In __preprocessing__ we will deal with erronous and missing values of columns.
# - Again we will do __pandas profiling__ to see how preprocessing have transformed our dataset.

# %% [markdown]
# ### 4.1 Understanding the dataset <a class="anchor" id="section41"></a>

# %% [markdown]
# We will get some insights of data and investigate it cautiously in this section, we will observe the data of few rows from the dataset.

# %%
IPLdf.shape #Checking Number of Rows and Columns present in Dataset
# Out:
# (696, 18)

# %% [markdown]
# __IPL__ Dataset contains __696 rows and 18 columns__.

# %%
IPLdf.columns #To check all the columns present in the Data Set
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
IPLdf.info() #To check the index,datatype and memory information of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 18 columns):
# id                 696 non-null int64
# season             696 non-null int64
# city               689 non-null object
# date               696 non-null object
# team1              696 non-null object
# team2              696 non-null object
# toss_winner        696 non-null object
# toss_decision      696 non-null object
# result             696 non-null object
# dl_applied         696 non-null int64
# winner             693 non-null object
# win_by_runs        696 non-null int64
# win_by_wickets     696 non-null int64
# player_of_match    693 non-null object
# venue              696 non-null object
# umpire1            695 non-null object
# umpire2            695 non-null object
# umpire3            60 non-null object
# dtypes: int64(5), object(13)
# memory usage: 98.0+ KB

# %% [markdown]
# We are checking __data type__, __memory information__ of each column above.

# %%
IPLdf.head() #Checking 1st 5 rows in the dataset
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
IPLdf.tail() #Checking last 5 rows in the datset
# Out:
#        id  season     city      date                  team1  \
# 691  7949    2018     Pune  20/05/18        Kings XI Punjab
# 692  7950    2018   Mumbai  22/05/18    Sunrisers Hyderabad
# 693  7951    2018  Kolkata  23/05/18  Kolkata Knight Riders
# 694  7952    2018  Kolkata  25/05/18    Sunrisers Hyderabad
# 695  7953    2018   Mumbai  27/05/18    Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# 691    Chennai Super Kings    Chennai Super Kings         field  normal
# 692    Chennai Super Kings    Chennai Super Kings         field  normal
# 693       Rajasthan Royals       Rajasthan Royals         field  normal
# 694  Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 695    Chennai Super Kings    Chennai Super Kings         field  normal
#
#      dl_applied                 winner  win_by_runs  win_by_wickets  \
# 691           0    Chennai Super Kings            0               5
# ...

# %%
IPLdf.describe() # To Check the statsticial information of number columns
# Out:
#                 id       season  dl_applied  win_by_runs  win_by_wickets
# count   696.000000   696.000000  696.000000   696.000000      696.000000
# mean    974.103448  2012.965517    0.027299    13.472701        3.349138
# std    2143.239623     3.069266    0.163070    23.607994        3.411398
# min       1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%     174.750000  2010.000000    0.000000     0.000000        0.000000
# 50%     348.500000  2013.000000    0.000000     0.000000        3.000000
# 75%     522.250000  2016.000000    0.000000    19.000000        6.000000
# max    7953.000000  2018.000000    1.000000   146.000000       10.000000

# %% [markdown]
# We are checking the __statstical information__ of columns having number data type as above.

# %%
IPLdf['team2'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Daredevils',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rajasthan Royals', 'Chennai Super Kings', 'Deccan Chargers',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype=object)

# %% [markdown]
# From above, we can see __Rising Pune Supergiant__ has been misspelled, we will replace it.

# %%
IPLdf.replace(['Rising Pune Supergiants'], ['Rising Pune Supergiant'], inplace= True) #Replacing the value
IPLdf['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors'], dtype=object)

# %%
IPLdf.isnull().sum() #Checking each column have how many null values.
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %% [markdown]
# We can see from above umpire3 column has __more than 70%__ null values.

# %% [markdown]
# ### 4.2 Pre Profiling <a class = "anchor" id = "section42"></a>

# %% [markdown]
# - By pandas profiling, an __interactive HTML report__ gets generated which contins all the information about the columns of the dataset, like the __counts and type__ of each _column_. Detailed information about each column, __coorelation between different columns__ and a sample of dataset.<br/>
# - It gives us __visual interpretation__ of each column in the data.
# - _Spread of the data_ can be better understood by the distribution plot.
# - _Grannular level_ analysis of each column.

# %%
profile = pp.ProfileReport(IPLdf)
profile.to_file(outputfile = "IPLbefproc.html")

# %% [markdown]
# We have done before preprocessing through __Pandas Profiling__ on our dataset and named the html file as __IPLbefproc.html__. We will have a look at the report to better understand it and develop some useful insight from it. <br/>
# Now we will process our data to better understand it.

# %% [markdown]
# ### 4.3 Pre Processing  <a class = "anchor" id = "section43"></a>

# %% [markdown]
# - Dealing with missing values
#     - Dropping Umpire column as it has more than 70% missing values.
#     - Replacing missing values of city with Dubai as its missing only for Dubai Internation Stadium.

# %%
IPLdf.drop('umpire3', axis = 1,inplace = True)

# %%
IPLdf['city'].fillna('Dubai',inplace = True)#Replacing Values of NaN with Dubai as itsonly for Dubai Stadium

# %% [markdown]
# ‘__dl_applied__’ column values are not meaningful, so we are mapping __0 to ‘No’(Not Applied)__ and __1 to ‘Yes’(Applied)__.

# %%
IPLdf['dl_applied'] = IPLdf['dl_applied'].map({0:'No', 1: 'Yes'})

# %%
IPLdf.head(2)#Checking Values in dl_applied column Yes/No
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal         No     Sunrisers Hyderabad           35               0
# 1  normal         No  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2
# 0  NJ Llong
# 1    S Ravi

# %% [markdown]
# We are adding a new column Match_type that helps us in knowing the type of match whether it is __'Pre-Qualifier', 'Qualifier-1','Qualifier-2','Eliminator' or 'Final'__.

# %%
IPLdf["Match_type"] = "Pre-Qualifier"
for year in range(2008, 2019):
   final_match_index = IPLdf[IPLdf['season']==year][-1:].index[0]
   IPLdf = IPLdf.set_value(final_match_index, "Match_type", "Final")
   IPLdf = IPLdf.set_value(final_match_index-1, "Match_type", "Qualifier-2")
   IPLdf = IPLdf.set_value(final_match_index-2, "Match_type", "Eliminator")
   IPLdf = IPLdf.set_value(final_match_index-3, "Match_type", "Qualifier-1")

# %% [markdown]
# ### 4.4 Post Profiling <a class = "anchor" id = "section44"></a>

# %%
profile = pp.ProfileReport(IPLdf)
profile.to_file(outputfile="IPLdfafterproc.html")

# %% [markdown]
# Now as we have preprocessed the data, now the dataset doesnt contain missing values, we have also introduced new feature named __Match_type__. So, the pandas profiling report which we have generated after preprocessing will give us more useful insights. We can compare the two reports, i.e __IPLdfafterproc.html__ and __IPLbefproc.html__.<br/>
# In __IPLdfafterproc.html__ report, observations:
# - In the Dataset info, Total __Missing(%)__ = __0.1%__ as we have not filled Nan values in umpire1,umpire2,player of match and winner columns. __Umpire Values__ will not be required for our analysis. __Player of match and winner__ is missing in case where __no result__ was there..
# - Number of __variables__ = __18__
# - Newly added variable __Match_type__ that gives us type of match i.e Pre-Qualifier, Eliminator, Final etc..

# %% [markdown]
# ### 5. Questions <a class = "anchor" id = "section5"></a>

# %% [markdown]
# ### 5.01 How many matches and seasons we have in our dataset ? <a class = "anchor" id = "section501"></a>

# %%
Totmatches = len(IPLdf['id']) #Checking Total number of matches in the dataset
print('Total number of matches in dataset are {} '.format(Totmatches))
# Out:
# Total number of matches in dataset are 696

# %%
Totseasons = len(IPLdf['season'].unique()) #checking Total number of seasons in the dataset
print('Total number of seasons in dataset are {} '.format(Totseasons))
# Out:
# Total number of seasons in dataset are 11

# %% [markdown]
# ### 5.02 How many  number of toss won by teams ? <a class = "anchor" id = "section502"></a>

# %%
# Number of Toss won by each team
print('The number of toss won by each team in a game')
Toss_wins= pd.DataFrame(IPLdf.groupby('toss_winner')['toss_winner'].count()) #Checking Count of Toss won by teams
Toss_wins.columns = ['Count'] #Setting Column name to count
Toss_wins = Toss_wins.reset_index() #Resetting the index
print(Toss_wins) # Printing the values
# Out:
# The number of toss won by each team in a game
#                     toss_winner  Count
# 0           Chennai Super Kings     77
# 1               Deccan Chargers     43
# 2              Delhi Daredevils     80
# 3                 Gujarat Lions     15
# 4               Kings XI Punjab     75
# 5          Kochi Tuskers Kerala      8
# 6         Kolkata Knight Riders     87
# 7                Mumbai Indians     90
# 8                 Pune Warriors     20
# 9              Rajasthan Royals     69
# 10       Rising Pune Supergiant     13
# 11  Royal Challengers Bangalore     77
# 12          Sunrisers Hyderabad     42

# %%
plt.figure(figsize = (8,5)) #Setting Graph Size
sns.barplot(y='toss_winner', x = 'Count', data = Toss_wins, palette = 'rainbow') #Bar Plot of Count versus toss winner
plt.title(' Number of Toss Won by each Team') #Setting graph title
plt.ylabel('Teams') #Setting Y-axis Label
plt.xlabel('Count') #Setting X-axis Label
plt.show() #Displaying the Plot

# %% [markdown]
# From above output and graph, we can clearly see that __Mumbai Indians, Kolkata Knight Riders and Delhi Daredevils__ have good fortune with the coin.

# %% [markdown]
# ### 5.03 What have teams preferred after winning the toss ? <a class = "anchor" id = "section503"></a>

# %%
plt.figure(figsize = (10,5)) #Setting Graph Size
sns.countplot(hue='toss_decision', y='toss_winner', data= IPLdf, palette= 'YlOrBr') #Bar Plot of Count versus toss winner
plt.title('Toss Decision By Teams') #Setting graph title
plt.xlabel('Count') #Setting X-axis Label
plt.ylabel('Team Name') #Setting Y-axis Label
plt.show() #Displaying the Plot

# %% [markdown]
# From above graph, we can see that teams have preffered to __field__ first so that they can plan their innings accordingly while batting 2nd.

# %% [markdown]
# ### 5.04 Has toss winning helped team in winning matches ? <a class = "anchor" id = "section504"></a>

# %%
plt.figure(figsize = (4,4)) #Setting Graph Size
data = IPLdf['toss_winner']  == IPLdf['winner'] #Checking if winning team has won toss or not
sns.countplot(data) #Countplot for Toss_wins versus count
plt.title('Has Toss winner won the match')#Setting the title
plt.xlabel('Toss win') #Setting X-axis Label
plt.ylabel('Count') #Setting Y-axis Label
plt.show() #Displaying the Plot

# %% [markdown]
# From above countplot, we can see that there are more cases where __toss winning__ has helped team __winning__ more number of matches i.e toss winning actually helps team winning matches.

# %% [markdown]
# ### 5.05 Has choosing bat/bowl helped team in winning matches ? <a class = "anchor" id =  "section505"></a>

# %%
plt.figure(figsize = (4,4)) #Setting Graph Size
data1 = IPLdf.toss_decision[IPLdf['toss_winner'] == IPLdf['winner']] #Checking if batting/fielding helped team winning the match 
sns.countplot(data1) #Count Plot 
plt.title('Toss Decision Plot')
plt.xlabel('Toss Decision') #Setting X-axis Label
plt.ylabel('Count') #Setting Y-axis Label
plt.show() #Displaying Bar Graph

# %% [markdown]
# From above output, we can see that chossing __field__ 1st to __toss_winner__ has helped in winning more number of matches.

# %% [markdown]
# ### 5.06 Which team has won by maximum runs ? <a class = "anchor" id = "section506"></a>

# %%
IPLdf.iloc[IPLdf['win_by_runs'].idxmax()] # Team won by maximum runs
# Out:
# id                               44
# season                         2017
# city                          Delhi
# date                     2017-05-06
# team1                Mumbai Indians
# team2              Delhi Daredevils
# toss_winner        Delhi Daredevils
# toss_decision                 field
# result                       normal
# dl_applied                       No
# winner               Mumbai Indians
# win_by_runs                     146
# win_by_wickets                    0
# player_of_match         LMP Simmons
# venue              Feroz Shah Kotla
# umpire1                 Nitin Menon
# umpire2                   CK Nandan
# Match_type            Pre-Qualifier
# Name: 43, dtype: object

# %% [markdown]
# From above output,we can see that __Mumbai Indian__ has won by __144 Runs__ in a Pre- Qualifier match against __Delhi Daredevils__ in season __2017__.

# %%
IPLdf[IPLdf[IPLdf['win_by_runs'].ge(1)].win_by_runs.max() == IPLdf['win_by_runs']]['winner']  
#Checking not more than one team has won by same number of max runs
# Out:
# 43    Mumbai Indians
# Name: winner, dtype: object

# %% [markdown]
# ### 5.07 Which team has won by maximum wickets ? <a class = "anchor" id = "section507"></a>

# %%
IPLdf.iloc[IPLdf['win_by_wickets'].idxmax()] # Team won by maximum wickets
# Out:
# id                                                      3
# season                                               2017
# city                                               Rajkot
# date                                           2017-04-07
# team1                                       Gujarat Lions
# team2                               Kolkata Knight Riders
# toss_winner                         Kolkata Knight Riders
# toss_decision                                       field
# result                                             normal
# dl_applied                                             No
# winner                              Kolkata Knight Riders
# win_by_runs                                             0
# win_by_wickets                                         10
# player_of_match                                   CA Lynn
# venue              Saurashtra Cricket Association Stadium
# umpire1                                       Nitin Menon
# ...

# %% [markdown]
# From above output,we can see that __Kolkata Knight Riders__ has won by __10 Wickets__ in a Pre- Qualifier match against __Gujrat Lions__ in season __2017__ ,there could be more than one instance also of team winning by 10 wickets.

# %%
IPLdf[IPLdf[IPLdf['win_by_wickets'].ge(1)].win_by_wickets.max() == IPLdf['win_by_wickets']]['winner']
#Checking for more than one instance of team team winning by maximum wickets
# Out:
# 2            Kolkata Knight Riders
# 34                 Kings XI Punjab
# 71                 Deccan Chargers
# 119               Delhi Daredevils
# 183    Royal Challengers Bangalore
# 298               Rajasthan Royals
# 376                 Mumbai Indians
# 390            Chennai Super Kings
# 542    Royal Challengers Bangalore
# 590            Sunrisers Hyderabad
# 683    Royal Challengers Bangalore
# Name: winner, dtype: object

# %% [markdown]
# From above output, we can see that there are __11 instances__ across all seasons where a team won by __10 wickets__.

# %% [markdown]
# ### 5.08 Which teams has won by minimum runs ? <a class = "anchor" id = "section508"></a>

# %%
IPLdf.iloc[IPLdf[IPLdf['win_by_runs'].ge(1)].win_by_runs.idxmin()] # Team won by minimum runs
# Out:
# id                                                        59
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-05-21
# team1                                         Mumbai Indians
# team2                                 Rising Pune Supergiant
# toss_winner                                   Mumbai Indians
# toss_decision                                            bat
# result                                                normal
# dl_applied                                                No
# winner                                        Mumbai Indians
# win_by_runs                                                1
# win_by_wickets                                             0
# player_of_match                                    KH Pandya
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %% [markdown]
# From above output, we can see that __Mumbai Indian__ has won by __1 Run__ in Final match against __Rising Pune Supergiant__ in season __2017__ , there could be more than one instance as well for same.

# %%
IPLdf[IPLdf[IPLdf['win_by_runs'].ge(1)].win_by_runs.min() == IPLdf['win_by_runs']]['winner']
#Checking for more than one instance of team team winning by minimum run i.e 1
# Out:
# 58                  Mumbai Indians
# 105                Kings XI Punjab
# 163                Kings XI Punjab
# 344               Delhi Daredevils
# 350                 Mumbai Indians
# 518            Chennai Super Kings
# 598                  Gujarat Lions
# 614    Royal Challengers Bangalore
# Name: winner, dtype: object

# %% [markdown]
# From above output, we can see that there are __08 instances__ across all seasons where a team has won by narrow margin of __1 run__.

# %% [markdown]
# ### 5.09 Which teams has won by minimum wickets ? <a class = "anchor" id = "section509"></a>

# %%
IPLdf.iloc[IPLdf[IPLdf['win_by_wickets'].ge(1)].win_by_wickets.idxmin()] # Team won by  minimum wickets
# Out:
# id                                   560
# season                              2015
# city                             Kolkata
# date                          2015-05-09
# team1                    Kings XI Punjab
# team2              Kolkata Knight Riders
# toss_winner              Kings XI Punjab
# toss_decision                        bat
# result                            normal
# dl_applied                            No
# winner             Kolkata Knight Riders
# win_by_runs                            0
# win_by_wickets                         1
# player_of_match               AD Russell
# venue                       Eden Gardens
# umpire1                     AK Chaudhary
# umpire2                  HDPK Dharmasena
# Match_type                 Pre-Qualifier
# Name: 559, dtype: object

# %% [markdown]
# From above output, we can see that __Kolkata Knight Riders__ has won by __1 Wicket__ in Pre-Qualifier match against __Kings XI Punjab__ in season __2015__, there could be more than one instance as well for same.

# %%
IPLdf[IPLdf[IPLdf['win_by_wickets'].ge(1)].win_by_wickets.min() == IPLdf['win_by_wickets']]['winner']
#Checking for more than one instances of winning by minimum wicket i.e 1
# Out:
# 559    Kolkata Knight Riders
# 636      Chennai Super Kings
# 642      Sunrisers Hyderabad
# Name: winner, dtype: object

# %% [markdown]
# From above output, we can see that there are __03 instances__ across all seasons where a team has won by narrow margin of __1 wicket__.

# %% [markdown]
# ### 5.10 Which are the best chasing and defending venues ? <a class = "anchor" id = "section510"></a>

# %%
# Top 5 Best chasing venues
Bchvenue = pd.DataFrame(IPLdf[IPLdf['win_by_wickets'] > 0]) #Checking where win by wickets greater than zero
Bchvenue = pd.DataFrame(Bchvenue.groupby('venue')['win_by_wickets'].count()) # Checking count of venues
Bchvenue.columns = ['Count'] #Setting column name
Top5Bchvenue = Bchvenue.sort_values(by = ['Count'],ascending = False) #sorting the counts
Top5Bchvenue = Top5Bchvenue.reset_index() #Resetting the index
Top5Bchvenue = Top5Bchvenue.head()  #Checking Top5values
Top5Bchvenue #Pring Top 5 Best Chasing Venues
# Out:
#                                        venue  Count
# 0                               Eden Gardens     41
# 1                      M Chinnaswamy Stadium     40
# 2                           Feroz Shah Kotla     33
# 3                           Wankhede Stadium     33
# 4  Rajiv Gandhi International Stadium, Uppal     32

# %%
plt.figure(figsize=(5,5)) # Setting the size
ax = sns.barplot(y = Top5Bchvenue['Count'], x = Top5Bchvenue['venue']) #Barplot of count versus best chasing venues
plt.title('Top5 Best Chasing Venues') # Setting Title
ax.set_xticklabels(ax.get_xticklabels() , rotation = 80) # Setting x axis labels to 80 degree
plt.xlabel('Best Chasing Venues') # Setting X-axis label
plt.ylabel('Win Count while Chasing')# Setting Y-axis labels
plt.show()  #Displaying the Graph

# %% [markdown]
# From above Data and Bar Graph, we can see that while chasing, __41 Matches__ have been won at __Eden Gardens__ making it best chasing venue among all the venues.

# %%
# Top 5 Best chasing venues
Bdefvenues = pd.DataFrame(IPLdf[IPLdf['win_by_runs'] > 0]) # Checking win_by_runs greater than zero
Bdefvenues = pd.DataFrame(Bdefvenues.groupby('venue')['win_by_runs'].count()) #Checking count of venues
Bdefvenues.columns = ['Count'] #Setting Column name
Top5Bdefvenues = Bdefvenues.sort_values(by = ['Count'],ascending = False) #Sortingthe Values
Top5Bdefvenues = Top5Bdefvenues.reset_index() #Resetting the index
Top5Bdefvenues = Top5Bdefvenues.head() #Checking Top5 Values
Top5Bdefvenues # Displaying Top5 Best Defending Venues
# Out:
#                              venue  Count
# 0                 Wankhede Stadium     33
# 1                 Feroz Shah Kotla     33
# 2  MA Chidambaram Stadium, Chepauk     30
# 3            M Chinnaswamy Stadium     30
# 4                     Eden Gardens     29

# %%
plt.figure(figsize=(5,5)) # Setting the size
ax = sns.barplot(y = Top5Bdefvenues['Count'], x = Top5Bdefvenues['venue']) # Bar Graph for Count versus Top5 best defending venues
plt.title('Top5 Best Defending Venues') # Setting Graph label
ax.set_xticklabels(ax.get_xticklabels() , rotation = 80) 
plt.xlabel('Best Defending Venues') # Setting x-axis Label
plt.ylabel('Win Count while Defending') #Setting Y-axis Label
plt.show() #Displaying the Graph

# %% [markdown]
# From above Data and Bar Graph, we can see that while defending __Wankhede Stadium and Feroz Shah Kotla__ are among best defending venues with count __33__ each while defending.

# %% [markdown]
# ### 5.11 Which is best defending and chasing team ? <a class = "anchor" id = "section511"></a>

# %%
Bdefteam = IPLdf.winner[IPLdf.win_by_runs != 0].mode()[0]  # Checking the best Defending Team
print('The best defending team among all IPL season is {}'.format(Bdefteam))
# Out:
# The best defending team among all IPL season is Mumbai Indians

# %%
plt.figure(figsize=(12,12)) # Setting the size 
sns.swarmplot(x='win_by_runs', y='winner',data= IPLdf) #Swarm Plot for Win_by_runs versus Winner 
plt.title('Win by runs versus Team to check best defending team') #Setting the Title of Grsph
plt.xlim(0.5,150) #Setting X-axis limit
plt.show() #Displayingthe Graph

# %% [markdown]
# From above Graph, we can see that __Mumbai Indians__ is best defending team.

# %%
Bchteam = IPLdf.winner[IPLdf.win_by_wickets != 0].mode()[0] # Best Chasing Team
print('The best chasing team among all IPL season is {}'.format(Bchteam))
# Out:
# The best chasing team among all IPL season is Kolkata Knight Riders

# %%
plt.figure(figsize=(12,12)) # Setting the Graph Size
sns.swarmplot(x='win_by_wickets', y='winner',data= IPLdf) # Swarm Plot for win_by_wickets versus winner 
plt.title('Win by wickets versus Team to check best defending team') # Setting the Title
plt.xlim(0.5,12) # Setting X-axis limit
plt.show() #Displaying the Graph

# %% [markdown]
# Above Graph deduce, __Kolkata Knight Riders__ is best Chasing Team.

# %% [markdown]
# ### 5.12 Which teams have played more number of matches ? <a class = "anchor" id =  "section512"></a>

# %%
T1 = pd.DataFrame(IPLdf.groupby('team1')['team2'].count()) # Grouping by Team 1 and checking count
T2 = pd.DataFrame(IPLdf.groupby('team2')['team2'].count()) # Grouping by Team 2 and checking count
Total = T1 + T2 # Checking total number of Teams and their Count 
Total = Total.reset_index() # Resetting the index
Total.columns = ['Team','Count' ] # Setting Column Names 
Match_count = Total.sort_values(by = ['Count'], ascending = False) #Sorting the Values
Match_count = Match_count.reset_index(drop = True) # Resetting the index
Match_count
# Out:
#                            Team  Count
# 0                Mumbai Indians    171
# 1   Royal Challengers Bangalore    166
# 2         Kolkata Knight Riders    164
# 3               Kings XI Punjab    162
# 4              Delhi Daredevils    161
# 5           Chennai Super Kings    147
# 6              Rajasthan Royals    133
# 7           Sunrisers Hyderabad     93
# 8               Deccan Chargers     75
# 9                 Pune Warriors     46
# 10                Gujarat Lions     30
# 11       Rising Pune Supergiant     30
# 12         Kochi Tuskers Kerala     14

# %%
plt.figure(figsize = (5,5)) # Setting Graph Size
sns.barplot(x = Match_count['Count'], y = Match_count['Team']) # Bar Plot of NCount versus Teams
plt.title('Matches Played by Teams') # Setting the Graph title
plt.xlabel('Count') # Setting X-axis Label
plt.ylabel('Teams') # Setting Y-axis Label 
plt.show() #Displaying the Graph

# %% [markdown]
# From above data, we can see that __Mumbai Indians__ , __Royal Challengers Bangalore__ and __Kolkata Knight Riders__ have played more matches among all teams.

# %% [markdown]
# ### 5.13 Count of matches won per season for each team ? <a class = "anchor" id =  "section513"></a>

# %%
plt.figure(figsize=(12,9)) # Setting the Graph Size
sns.countplot(y='winner', hue = 'season', data = IPLdf, palette = 'Set1') # Count Plot of wins for all seasons for all teams 
plt.title('Matches won by teams per season') # Setting the Graph title
plt.xlabel('Count') # Setting X-axis Label
plt.ylabel('Teams') # Setting Y-axis Label
plt.show() # Displaying the Graph

# %% [markdown]
# Some teams played few seasons only, so data is missing for them. __Chennai__ seems to be balanced with winning result.
# Trophy winners have spikes in the year when they have won the trophy.

# %% [markdown]
# ### 5.14 Which teams have won more number of matches ? <a class = "anchor" id =  "section514"></a>

# %%
Winner = pd.DataFrame(IPLdf.groupby('winner')['winner'].count()) # Checking The winners
Winner.columns = ['Count'] #Setting the Column Name
Winner = Winner.sort_values(by = ['Count'],ascending = False) # Sorting the Values
Winner = Winner.reset_index() # Resetting the index
Winner # Printing the values
# Out:
#                          winner  Count
# 0                Mumbai Indians     98
# 1           Chennai Super Kings     90
# 2         Kolkata Knight Riders     86
# 3   Royal Challengers Bangalore     79
# 4               Kings XI Punjab     76
# 5              Rajasthan Royals     70
# 6              Delhi Daredevils     67
# 7           Sunrisers Hyderabad     52
# 8               Deccan Chargers     29
# 9        Rising Pune Supergiant     15
# 10                Gujarat Lions     13
# 11                Pune Warriors     12
# 12         Kochi Tuskers Kerala      6

# %%
Mostwins = IPLdf.winner.value_counts() # Checking Count of Winners
plt.figure(figsize = (5,5)) # Setting the Graph Size
ax = sns.barplot(x = Mostwins, y = Mostwins.index) # Bar Plot of Count versus Teams
plt.title('Matches won by Teams') # Setting Graph Title
plt.xlabel('Count of Matches') # Setting X-axis Label
plt.ylabel('Teams') # Setting Y-axis Label
plt.show() # Displaying the Graph

# %% [markdown]
# From above data and graph, we can see that __Mumbai Indians__ , __Chennai Super Kings__ and __Kolkata Knight Riders__ are the top winning teams. These three teams are most successful teams in IPL history till now.

# %% [markdown]
# ### 5.15 Which season has most number of matches ? <a class = "anchor" id =  "section515"></a>

# %%
plt.figure(figsize = (8,4)) # Setting the Graph Size
sns.countplot(x = 'season', data = IPLdf) # Countplot Season versus matches played 
plt.xlabel('Season') # Setting X-axis Label
plt.ylabel('Count') # Setting Y-axis Label
plt.title('Count of matches per season') # Setting Graph Title
plt.show() # Displaying the Graph

# %% [markdown]
# From above output, we can see that seson __2013__ has most number of matches among all seasons.

# %% [markdown]
# ### 5.16 Who are top match winners ? <a class = "anchor" id =  "section516"></a>

# %%
plt.figure(figsize = (6,4)) # Setting the Graph Size
Match_winners = IPLdf['player_of_match'].value_counts()[:10] # Getting Top 10 match winners
ax = sns.barplot(x = Match_winners.index, y = Match_winners) # Bar Plot for Player of the Match versus Count
ax.set_title('Top Match Winners') # Setting Graph Title
ax.set_xticklabels(ax.get_xticklabels() , rotation = 90)
plt.xlabel('Player Name') # Setting X-axis Label
plt.ylabel('Count') # Setting Y-axis Label
plt.show() # Displaying the Graph

# %% [markdown]
# From above data, we can see __Top 10__ match winners among all seasons where __Chris Gayle__ is topping the chart with __20 Player of Match__ award.

# %% [markdown]
# ### 5.17 In which city weather has affected more matches ? <a class = "anchor" id =  "section517"></a>

# %%
plt.figure(figsize = (8,4)) # Setting the Graph Size
DL = IPLdf.city[IPLdf['dl_applied'] == 'Yes'] 
ax = sns.countplot(DL) # Count Plot for Effect of weather on Matches
ax.set_xticklabels(ax.get_xticklabels() , rotation = 60) #Setting X-axis Label values to 60 degree
plt.xlabel('Cities') # Setting X-axis Label
plt.ylabel('Count') # Setting Y-axis Label
plt.title('Effect of weather on matches in different Cities') # Setting Graph Title
plt.show() # Displaying the Graph

# %% [markdown]
# From above output, we can see weather has affected most number of matchesin __Kolkata__.

# %% [markdown]
# ### 5.18 Checking corelation between different variables ? <a class = "anchor" id =  "section518"></a>

# %%
plt.figure(figsize = (5,5)) # Setting the Graph Size
Corelation = IPLdf.corr() #Checking Correlation
sns.heatmap(Corelation,annot = True, cmap = 'Reds') # Heatmap for Correlation between diff varables
plt.show() # Displaying the Graph

# %% [markdown]
# From the above heatmap diagram, we can see there is negative corelation between __'win by runs' and 'win by wickets'__ and we know that if one value is zero other will be non zero.

# %% [markdown]
# ### 5.19 Which team has won most IPL Trophies ? <a class = "anchor" id =  "section519"></a>

# %%
plt.figure(figsize = (7,4)) # Setting the Graph Size
Final_winners = IPLdf.winner[IPLdf['Match_type'] == 'Final'].value_counts()[:3] # Getting top 3 final winning teams 
ax = sns.barplot(x = Final_winners.index, y = Final_winners) # Setting Variables in barplot x and y axis variables in bar plot
ax.set_title('Top 3 IPL winning Teams') # Setting Graph Title
plt.xlabel('Teams') # Setting X-axis Label
plt.ylabel('Count') # Setting Y-axis Label
plt.show() # Showing bar graph

# %% [markdown]
# From above output, we can see that __Chennai Super Kings and Mumbai Indians__ has won the IPL thrice whereas __Kolkata Knight Riders__ won it twice.

# %% [markdown]
# ### 5.20 Distribution of winning teams  percentage throughout ? <a class = "anchor" id =  "section520"></a>

# %%
plt.figure(figsize = (9,9)) # Setting Graph Size 
plt.pie(Winner['Count'], labels = Winner.winner, autopct='%.2f') # Pie Chart of team wins for all teams
plt.show() # Displaying Graph

# %% [markdown]
# From above pie chart, we can see that __Mumbai Indians and Chennai Super Kings and Kolkata Knight riders__ are the top teams of IPL.

# %% [markdown]
# ### 6. Conclusion <a class = "anchor" id =  "section600"></a>

# %% [markdown]
# - This notebook helps us understanding how Exploratory Data Analysis carried out using different python packages i.e pandas,pandas_profiling, seaborn, matplotlib etc.
# - Pandas helps us in __maipulating__ the data whereas __matplotlib and seaborn__ to visualise the data and get better insights.
# - We also make use of __pandas profiling__ feature to generate an html report containing all the information of the various features present in the dataset.
# - We have also seen how __pre proceesing__ helps in dealing with data ambiguities.
# - We have seen the impact of columns like __Toss_decision, Toss_winner__ on winning team,also we added __Match_type__ column which gives us Top IPL winning teams.
# - We have also seen __Teams having good fortune with coin, Top match winners, Best chasing and defending teams as well as venues and top IPL winning teams__.
# - __Chennai and Mumbai__ are the top IPL teams winning 3 trophies each so far.
# - This analysis helped us in __getting meaningful insights__ from excel data.
# * __Actionable Insights :__ <br/>
# - __Eden Gardens and M Chinnaswamy Stadium__ are best Chasing Venues, so toss winner should choose to bowl first that will give an added advantage to the toss winning team.
# - __Wankhede Stadium and Feroz Shah Kotla__ are best defending Venues, so toss winner should choose to bat first that will give an added advantage to the toss winning team.
# - Same should be followed in case of __best defending and chasing teams__, they should back their strengh of chasing or defending the targetafter winning the toss.
# - __Royal Challengers Bangalore__ have played 2nd most number of matches but haven't won any of the trophies, their team management should focus on their players mental strength in high current games.
# - Chris Gayle, AB Devilliers are top match winners so team owners should focus on buying these players in upcoming seasons or opposite team should make good strategies to get them out soon.
# - __Mumbai, Chennai and Kolkata__ have collectively won 8 season out of 11 seasons happened so far, opposite teams should prepare strong strategy while playing against these teams.
